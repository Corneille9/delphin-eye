# %%
from PIL import Image as PILImage
from matplotlib import pyplot as plt

# %%
def crop_image(path, x, y, w, h, margin= ):
    img = PILImage.open(path)
    iw, ih = img.size

    print(f"Image size: {w}x{h}")

    img = img.crop((

    ))

    plt.imshow(img)

    pass

crop_image('./../output/predictions/image0.jpg', 0.5, 0.5, 0.2, 0.2)
# <class_id> <x_center> <y_center> <width> <height>
# Out:
# Image size: 0.2x0.2
